# %%
import pandas as pd
location = "C:\\blp\\data\\mtg_bex.txt"

# %%
df = pd.read_csv(location, skiprows=1, sep="\t").reset_index()

# %%
cols = df.iloc[0].tolist()
df.columns = cols
df = df.iloc[1:,:-1]

# %%
df
# Out:
#      As of Date Ticket Number Security Description Trader Name Buy/Sell  \
# 1    2018/06/13        658940            FN 252482      SVCMTG        B
# 2    2018/06/13        658640            FN 252482      SVCMTG        S
# 3    2018/06/13        656162          G2SF 4 6/18         M29        S
# 4    2018/06/13        656184          G2SF 4 7/18         M29        B
# 5    2018/06/13        654844          G2SF 4 8/18         M29        B
# 6    2018/06/13        655394          G2SF 4 7/18         M29        B
# 7    2018/06/13        654987            G2 MA5264         M29        B
# 8    2018/06/13        661511          G2SF 4 8/18         M29        S
# 9    2018/06/13        661513          G2SF 4 8/18         M29        B
# 10   2018/06/13        661515        G2SF 3.5 8/18         M29        S
# 11   2018/06/13        659909          FNCL 4 7/18         M29        B
# 12   2018/06/13        658811        G2SF 4.5 6/18         M29        B
# ...

# %%
loc2 = "C:\\blp\\data\\mbex"

# %%
df2 = pd.read_csv(location, skiprows=1, sep="\t").reset_index()
